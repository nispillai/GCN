# %% [markdown]
# PROTEINS is a dataset of proteins that are classified as enzymes or non-enzymes.
# Nodes represent the amino acids and two nodes are connected by an edge if they are less than 6 Angstroms apart.

# %%
import torch
from torch_geometric.datasets import TUDataset

dataset = TUDataset(root='data/TUDataset', name='PROTEINS')

# %%
data = dataset[0]  # 1st graph
 
print()
print(f'Dataset: {dataset}:')
print('====================')
# How many graphs?
print(f'Number of graphs: {len(dataset)}')
# How many features?
print(f'Number of features: {dataset.num_features}')
# Now, in our first graph, how many edges?
print(f'Number of edges: {data.num_edges}')
# Average node degree?
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
# Do we have isolated nodes?
print(f'Contains isolated nodes: {data.contains_isolated_nodes()}')
# Do we contain self-loops?
print(f'Contains self-loops: {data.contains_self_loops()}')
# Is this an undirected graph?
print(f'Is undirected: {data.is_undirected()}')
print(data)
# Out:
# Dataset: PROTEINS(1113):
# ====================
# Number of graphs: 1113
# Number of features: 3
# Number of edges: 162
# Average node degree: 3.86
# Contains isolated nodes: False
# Contains self-loops: False
# Is undirected: True
# Data(edge_index=[2, 162], x=[42, 3], y=[1])

# %%
torch.manual_seed(12345)
dataset = dataset.shuffle()
train_dataset = dataset[110:]
test_dataset = dataset[0:110]

# %%
from torch_geometric.data import DataLoader
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.nn import global_mean_pool
 

class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()        
        self.conv1 = GCNConv(dataset.num_node_features, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, dataset.num_classes)
        
    def forward(self, x, edge_index, batch):
      x = self.conv1(x, edge_index)
      x = x.relu()
      x = self.conv2(x, edge_index)
      x = x.relu()
      x = self.conv3(x, edge_index)   
      x = global_mean_pool(x, batch)  
      x = F.dropout(x, p=0.5, training=self.training)
      x = self.lin(x)
      return x
    
model = GCN(hidden_channels=64)
print(model)
# Out:
# GCN(
#   (conv1): GCNConv(3, 64)
#   (conv2): GCNConv(64, 64)
#   (conv3): GCNConv(64, 64)
#   (lin): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

criterion = torch.nn.CrossEntropyLoss()
 
def train():
    model.train()
 
    for data in train_loader:  
      out = model(data.x, data.edge_index, data.batch)  
      loss = criterion(out, data.y)  
      loss.backward()  
      optimizer.step()  
      optimizer.zero_grad()  

def test(loader):
  model.eval()
 
  correct = 0
  for data in loader:  
      out = model(data.x, data.edge_index, data.batch)  
      pred = out.argmax(dim=1)  
      correct += int((pred == data.y).sum())  
  return correct / len(loader.dataset)  
 

for epoch in range(1, 201):
    train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# Epoch: 001, Train Acc: 0.6351, Test Acc: 0.6091
# Epoch: 002, Train Acc: 0.6790, Test Acc: 0.6636
# Epoch: 003, Train Acc: 0.6481, Test Acc: 0.6818
# Epoch: 004, Train Acc: 0.6590, Test Acc: 0.7000
# Epoch: 005, Train Acc: 0.7129, Test Acc: 0.7273
# Epoch: 006, Train Acc: 0.6879, Test Acc: 0.7273
# Epoch: 007, Train Acc: 0.6740, Test Acc: 0.6636
# Epoch: 008, Train Acc: 0.7089, Test Acc: 0.7273
# Epoch: 009, Train Acc: 0.6889, Test Acc: 0.7000
# Epoch: 010, Train Acc: 0.6710, Test Acc: 0.6909
# Epoch: 011, Train Acc: 0.7168, Test Acc: 0.7273
# Epoch: 012, Train Acc: 0.6780, Test Acc: 0.6818
# Epoch: 013, Train Acc: 0.7149, Test Acc: 0.7091
# Epoch: 014, Train Acc: 0.6909, Test Acc: 0.6909
# Epoch: 015, Train Acc: 0.7119, Test Acc: 0.7000
# Epoch: 016, Train Acc: 0.7129, Test Acc: 0.7000
# Epoch: 017, Train Acc: 0.7238, Test Acc: 0.7364
# Epoch: 018, Train Acc: 0.7238, Test Acc: 0.7273
# Epoch: 019, Train Acc: 0.6849, Test Acc: 0.6727
# Epoch: 020, Train Acc: 0.7228, Test Acc: 0.7273
# Epoch: 021, Train Acc: 0.6939, Test Acc: 0.6909
# Epoch: 022, Train Acc: 0.6869, Test Acc: 0.6545
# Epoch: 023, Train Acc: 0.6690, Test Acc: 0.6636
# Epoch: 024, Train Acc: 0.7218, Test Acc: 0.7273
# Epoch: 025, Train Acc: 0.7149, Test Acc: 0.6909
# Epoch: 026, Train Acc: 0.7218, Test Acc: 0.7182
# Epoch: 027, Train Acc: 0.6999, Test Acc: 0.6909
# Epoch: 028, Train Acc: 0.7159, Test Acc: 0.7000
# Epoch: 029, Train Acc: 0.6979, Test Acc: 0.7000
# Epoch: 030, Train Acc: 0.6959, Test Acc: 0.6727
# Epoch: 031, Train Acc: 0.6810, Test Acc: 0.6727
# Epoch: 032, Train Acc: 0.6790, Test Acc: 0.6909
# Epoch: 033, Train Acc: 0.6750, Test Acc: 0.6545
# Epoch: 034, Train Acc: 0.6770, Test Acc: 0.6545
# Epoch: 035, Train Acc: 0.6760, Test Acc: 0.6545
# Epoch: 036, Train Acc: 0.7129, Test Acc: 0.7182
# Epoch: 037, Train Acc: 0.6869, Test Acc: 0.7000
# Epoch: 038, Train Acc: 0.7338, Test Acc: 0.7182
# Epoch: 039, Train Acc: 0.7268, Test Acc: 0.7182
# Epoch: 040, Train Acc: 0.7248, Test Acc: 0.7273
# Epoch: 041, Train Acc: 0.7129, Test Acc: 0.7091
# Epoch: 042, Train Acc: 0.7218, Test Acc: 0.7182
# Epoch: 043, Train Acc: 0.7069, Test Acc: 0.6818
# Epoch: 044, Train Acc: 0.7079, Test Acc: 0.7000
# Epoch: 045, Train Acc: 0.7288, Test Acc: 0.7182
# Epoch: 046, Train Acc: 0.6899, Test Acc: 0.7000
# Epoch: 047, Train Acc: 0.7149, Test Acc: 0.7000
# Epoch: 048, Train Acc: 0.6969, Test Acc: 0.7091
# Epoch: 049, Train Acc: 0.7079, Test Acc: 0.7000
# Epoch: 050, Train Acc: 0.6830, Test Acc: 0.6909
# Epoch: 051, Train Acc: 0.6889, Test Acc: 0.6909
# Epoch: 052, Train Acc: 0.7198, Test Acc: 0.7273
# Epoch: 053, Train Acc: 0.7228, Test Acc: 0.7364
# Epoch: 054, Train Acc: 0.7159, Test Acc: 0.7091
# Epoch: 055, Train Acc: 0.6959, Test Acc: 0.7182
# Epoch: 056, Train Acc: 0.6610, Test Acc: 0.6636
# Epoch: 057, Train Acc: 0.7049, Test Acc: 0.7000
# Epoch: 058, Train Acc: 0.6869, Test Acc: 0.7000
# Epoch: 059, Train Acc: 0.7178, Test Acc: 0.7182
# Epoch: 060, Train Acc: 0.6899, Test Acc: 0.7091
# Epoch: 061, Train Acc: 0.6839, Test Acc: 0.6727
# Epoch: 062, Train Acc: 0.7029, Test Acc: 0.7182
# Epoch: 063, Train Acc: 0.7318, Test Acc: 0.7273
# Epoch: 064, Train Acc: 0.7268, Test Acc: 0.7182
# Epoch: 065, Train Acc: 0.7298, Test Acc: 0.7182
# Epoch: 066, Train Acc: 0.7178, Test Acc: 0.7091
# Epoch: 067, Train Acc: 0.6839, Test Acc: 0.6818
# Epoch: 068, Train Acc: 0.7159, Test Acc: 0.7091
# Epoch: 069, Train Acc: 0.7278, Test Acc: 0.7273
# Epoch: 070, Train Acc: 0.7109, Test Acc: 0.7182
# Epoch: 071, Train Acc: 0.6989, Test Acc: 0.7091
# Epoch: 072, Train Acc: 0.7019, Test Acc: 0.7000
# Epoch: 073, Train Acc: 0.7139, Test Acc: 0.7000
# Epoch: 074, Train Acc: 0.7049, Test Acc: 0.7273
# Epoch: 075, Train Acc: 0.7099, Test Acc: 0.7182
# Epoch: 076, Train Acc: 0.7278, Test Acc: 0.7091
# Epoch: 077, Train Acc: 0.7089, Test Acc: 0.7182
# Epoch: 078, Train Acc: 0.7288, Test Acc: 0.7091
# Epoch: 079, Train Acc: 0.7188, Test Acc: 0.7364
# Epoch: 080, Train Acc: 0.6919, Test Acc: 0.7182
# Epoch: 081, Train Acc: 0.7178, Test Acc: 0.7182
# Epoch: 082, Train Acc: 0.7149, Test Acc: 0.7273
# Epoch: 083, Train Acc: 0.7248, Test Acc: 0.7182
# Epoch: 084, Train Acc: 0.7019, Test Acc: 0.7000
# Epoch: 085, Train Acc: 0.7159, Test Acc: 0.6909
# Epoch: 086, Train Acc: 0.7328, Test Acc: 0.7273
# Epoch: 087, Train Acc: 0.7139, Test Acc: 0.6909
# Epoch: 088, Train Acc: 0.7218, Test Acc: 0.7273
# Epoch: 089, Train Acc: 0.7119, Test Acc: 0.7091
# Epoch: 090, Train Acc: 0.6939, Test Acc: 0.6818
# Epoch: 091, Train Acc: 0.7318, Test Acc: 0.7182
# Epoch: 092, Train Acc: 0.7079, Test Acc: 0.7091
# Epoch: 093, Train Acc: 0.6929, Test Acc: 0.7182
# Epoch: 094, Train Acc: 0.7188, Test Acc: 0.7000
# Epoch: 095, Train Acc: 0.7049, Test Acc: 0.7182
# Epoch: 096, Train Acc: 0.6830, Test Acc: 0.7182
# Epoch: 097, Train Acc: 0.7198, Test Acc: 0.7091
# Epoch: 098, Train Acc: 0.7159, Test Acc: 0.7182
# Epoch: 099, Train Acc: 0.7149, Test Acc: 0.6909
# Epoch: 100, Train Acc: 0.7288, Test Acc: 0.7182
# Epoch: 101, Train Acc: 0.7009, Test Acc: 0.7091
# Epoch: 102, Train Acc: 0.6859, Test Acc: 0.7455
# Epoch: 103, Train Acc: 0.7109, Test Acc: 0.7455
# Epoch: 104, Train Acc: 0.7039, Test Acc: 0.7091
# Epoch: 105, Train Acc: 0.7109, Test Acc: 0.7091
# Epoch: 106, Train Acc: 0.7318, Test Acc: 0.7273
# Epoch: 107, Train Acc: 0.7079, Test Acc: 0.7091
# Epoch: 108, Train Acc: 0.6810, Test Acc: 0.6727
# Epoch: 109, Train Acc: 0.7198, Test Acc: 0.7091
# Epoch: 110, Train Acc: 0.7119, Test Acc: 0.7091
# Epoch: 111, Train Acc: 0.7198, Test Acc: 0.6909
# Epoch: 112, Train Acc: 0.7188, Test Acc: 0.7273
# Epoch: 113, Train Acc: 0.7278, Test Acc: 0.7091
# Epoch: 114, Train Acc: 0.7248, Test Acc: 0.7000
# Epoch: 115, Train Acc: 0.6810, Test Acc: 0.7182
# Epoch: 116, Train Acc: 0.7149, Test Acc: 0.7000
# Epoch: 117, Train Acc: 0.7298, Test Acc: 0.7182
# Epoch: 118, Train Acc: 0.7238, Test Acc: 0.7091
# Epoch: 119, Train Acc: 0.7159, Test Acc: 0.7091
# Epoch: 120, Train Acc: 0.7218, Test Acc: 0.7273
# Epoch: 121, Train Acc: 0.7328, Test Acc: 0.7273
# Epoch: 122, Train Acc: 0.7258, Test Acc: 0.7091
# Epoch: 123, Train Acc: 0.6879, Test Acc: 0.6909
# Epoch: 124, Train Acc: 0.7129, Test Acc: 0.7091
# Epoch: 125, Train Acc: 0.7029, Test Acc: 0.7182
# Epoch: 126, Train Acc: 0.7089, Test Acc: 0.7091
# Epoch: 127, Train Acc: 0.7168, Test Acc: 0.7000
# Epoch: 128, Train Acc: 0.7348, Test Acc: 0.7273
# Epoch: 129, Train Acc: 0.6979, Test Acc: 0.7091
# Epoch: 130, Train Acc: 0.7079, Test Acc: 0.7455
# Epoch: 131, Train Acc: 0.6999, Test Acc: 0.7000
# Epoch: 132, Train Acc: 0.7178, Test Acc: 0.6909
# Epoch: 133, Train Acc: 0.7298, Test Acc: 0.7273
# Epoch: 134, Train Acc: 0.7079, Test Acc: 0.6909
# Epoch: 135, Train Acc: 0.7278, Test Acc: 0.7273
# Epoch: 136, Train Acc: 0.6710, Test Acc: 0.7091
# Epoch: 137, Train Acc: 0.7188, Test Acc: 0.7091
# Epoch: 138, Train Acc: 0.7258, Test Acc: 0.7091
# Epoch: 139, Train Acc: 0.7288, Test Acc: 0.7364
# Epoch: 140, Train Acc: 0.7168, Test Acc: 0.7000
# Epoch: 141, Train Acc: 0.7049, Test Acc: 0.7364
# Epoch: 142, Train Acc: 0.7099, Test Acc: 0.7273
# Epoch: 143, Train Acc: 0.6969, Test Acc: 0.7091
# Epoch: 144, Train Acc: 0.7168, Test Acc: 0.7000
# Epoch: 145, Train Acc: 0.7258, Test Acc: 0.7182
# Epoch: 146, Train Acc: 0.7208, Test Acc: 0.7091
# Epoch: 147, Train Acc: 0.7238, Test Acc: 0.6909
# Epoch: 148, Train Acc: 0.7089, Test Acc: 0.7000
# Epoch: 149, Train Acc: 0.7288, Test Acc: 0.7273
# Epoch: 150, Train Acc: 0.7119, Test Acc: 0.6727
# Epoch: 151, Train Acc: 0.7188, Test Acc: 0.7182
# Epoch: 152, Train Acc: 0.7139, Test Acc: 0.7000
# Epoch: 153, Train Acc: 0.7089, Test Acc: 0.7273
# Epoch: 154, Train Acc: 0.6919, Test Acc: 0.7364
# Epoch: 155, Train Acc: 0.7099, Test Acc: 0.7364
# Epoch: 156, Train Acc: 0.7188, Test Acc: 0.7455
# Epoch: 157, Train Acc: 0.7129, Test Acc: 0.7182
# Epoch: 158, Train Acc: 0.7318, Test Acc: 0.7000
# Epoch: 159, Train Acc: 0.7188, Test Acc: 0.7182
# Epoch: 160, Train Acc: 0.7159, Test Acc: 0.7182
# Epoch: 161, Train Acc: 0.7228, Test Acc: 0.7000
# Epoch: 162, Train Acc: 0.7009, Test Acc: 0.6636
# Epoch: 163, Train Acc: 0.7218, Test Acc: 0.7273
# Epoch: 164, Train Acc: 0.6889, Test Acc: 0.6909
# Epoch: 165, Train Acc: 0.7198, Test Acc: 0.7273
# Epoch: 166, Train Acc: 0.7029, Test Acc: 0.7000
# Epoch: 167, Train Acc: 0.7298, Test Acc: 0.7455
# Epoch: 168, Train Acc: 0.7129, Test Acc: 0.7091
# Epoch: 169, Train Acc: 0.6510, Test Acc: 0.6455
# Epoch: 170, Train Acc: 0.7159, Test Acc: 0.7182
# Epoch: 171, Train Acc: 0.7089, Test Acc: 0.7273
# Epoch: 172, Train Acc: 0.7248, Test Acc: 0.7455
# Epoch: 173, Train Acc: 0.7029, Test Acc: 0.6727
# Epoch: 174, Train Acc: 0.7168, Test Acc: 0.7182
# Epoch: 175, Train Acc: 0.7258, Test Acc: 0.7182
# Epoch: 176, Train Acc: 0.7228, Test Acc: 0.7091
# Epoch: 177, Train Acc: 0.7049, Test Acc: 0.7364
# Epoch: 178, Train Acc: 0.7188, Test Acc: 0.7273
# Epoch: 179, Train Acc: 0.7218, Test Acc: 0.7364
# Epoch: 180, Train Acc: 0.7149, Test Acc: 0.6727
# Epoch: 181, Train Acc: 0.7109, Test Acc: 0.6909
# Epoch: 182, Train Acc: 0.7149, Test Acc: 0.7455
# Epoch: 183, Train Acc: 0.7168, Test Acc: 0.7455
# Epoch: 184, Train Acc: 0.7139, Test Acc: 0.7182
# Epoch: 185, Train Acc: 0.7318, Test Acc: 0.7364
# Epoch: 186, Train Acc: 0.7258, Test Acc: 0.7455
# Epoch: 187, Train Acc: 0.7159, Test Acc: 0.7091
# Epoch: 188, Train Acc: 0.7278, Test Acc: 0.7455
# Epoch: 189, Train Acc: 0.7218, Test Acc: 0.7182
# Epoch: 190, Train Acc: 0.7079, Test Acc: 0.7182
# Epoch: 191, Train Acc: 0.7228, Test Acc: 0.7545
# Epoch: 192, Train Acc: 0.7019, Test Acc: 0.7364
# Epoch: 193, Train Acc: 0.7168, Test Acc: 0.7273
# Epoch: 194, Train Acc: 0.7039, Test Acc: 0.6818
# Epoch: 195, Train Acc: 0.7109, Test Acc: 0.7000
# Epoch: 196, Train Acc: 0.7218, Test Acc: 0.7091
# Epoch: 197, Train Acc: 0.6929, Test Acc: 0.7364
# Epoch: 198, Train Acc: 0.7248, Test Acc: 0.7000
# Epoch: 199, Train Acc: 0.7139, Test Acc: 0.7273
# Epoch: 200, Train Acc: 0.7029, Test Acc: 0.7455
